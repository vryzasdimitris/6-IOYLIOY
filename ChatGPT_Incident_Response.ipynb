# %% [markdown]
# <a href="https://colab.research.google.com/github/vryzasdimitris/6-IOYLIOY/blob/main/ChatGPT_Incident_Response.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#εγκατάσταση πακέτου transformers (https://pypi.org/project/transformers/)
# !pip install transformers
#εγκατάσταση πακέτου requests (https://pypi.org/project/requests/)
# !pip install requests
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)

# %%
#εισαγωγή βιβλιοθηκών - πακέτων
import pandas as pd
import torch
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from transformers import GPT2LMHeadModel, GPT2Tokenizer

#aπλό μοντέλο IDS για σκοπούς επίδειξης
class SimpleIDS:
    def __init__(self):
        #aρχικοποιήση ενός φορέα TF-IDF και ενός ταξινομητή Naive Bayes
        self.vectorizer = TfidfVectorizer()
        self.classifier = MultinomialNB()

    def train(self, data, labels):
        #εκπαίδευση μοντέλου
        vectorized_data = self.vectorizer.fit_transform(data)
        self.classifier.fit(vectorized_data, labels)

    def predict(self, text):
        #πρόβλεψη για τον εάν υπάρχει ή όχι επίθεση
        vectorized_text = self.vectorizer.transform([text])
        return self.classifier.predict(vectorized_text)[0]

#ενσωμάτωση ChatGPT για την υλοποίηση απόκρισης συμβάντων
class EnhancedChatGPTIncidentResponse:
    def __init__(self):
        #φόρτωση προεκπαιδευμένου μοντέλου ChatGPT
        self.tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
        self.model = GPT2LMHeadModel.from_pretrained("gpt2")

    def generate_response(self, incident_identification, incident_summary, incident_notification, actions):
        #δημιουργία μιας αναγνώσιμης από άνθρωπο απάντησης χρησιμοποιώντας το ChatGPT με ρητές ρυθμίσεις
        prompt = (
            f"INCIDENT IDENTIFICATION INFORMATION: {incident_identification}\n"
            f"INCIDENT SUMMARY: {incident_summary}\n"
            f"INCIDENT NOTIFICATION – OTHERS: {incident_notification}\n"
            f"ACTIONS: {actions}\n"
        )

        #προσαρμογή της προτροπής
        input_ids = self.tokenizer.encode(prompt, return_tensors="pt", max_length=150, truncation=True)

        #ρύθμιση της μάσκας προσοχής
        attention_mask = torch.ones(input_ids.shape, device=input_ids.device)

        #δημιουργία απάντησης με ρητές ρυθμίσεις
        output = self.model.generate(
            input_ids,
            attention_mask=attention_mask,
            max_length=300,
            num_return_sequences=1,
            no_repeat_ngram_size=2,
            pad_token_id=self.tokenizer.eos_token_id
        )

        #αποκοδικοποίηση της εξόδου
        response = self.tokenizer.decode(output[0], skip_special_tokens=True)
        return response

#δημιουργία συνθετικών δεδομένων
def generate_synthetic_data(num_samples):
    incident_identifications = [f"ID{i}" for i in range(1, num_samples + 1)]
    incident_summaries = ["Normal activity"] * (num_samples // 2) + ["SQL injection attempt"] * (num_samples // 2)
    incident_notifications = ["Security Team"] * num_samples
    actions = ["Monitor"] * (num_samples // 2) + ["Isolate and Investigate"] * (num_samples // 2)

    synthetic_data = pd.DataFrame({
        'IncidentIdentification': incident_identifications,
        'IncidentSummary': incident_summaries,
        'IncidentNotification': incident_notifications,
        'Actions': actions
    })

    return synthetic_data

#παράδειγμα χρήσης
if __name__ == "__main__":
    ids_model = SimpleIDS()
    enhanced_chatgpt_response = EnhancedChatGPTIncidentResponse()

    #παραγωγή δεδομένων σε ροές (batches)
    num_samples = 10
    synthetic_data = generate_synthetic_data(num_samples)

    #εκπαίδευση του IDS
    training_data = ["Normal network traffic", "SQL injection attempt", "Malicious file download"]
    training_labels = ["Normal", "Attack", "Attack"]

    try:
        ids_model.train(training_data, training_labels)
    except Exception as e:
        print(f"Error during training: {e}")

    #τύποι επιθέσεων
    attack_types = [
        "SQL injection attempt",
        "Malicious file download",
        "Ransomware",
        "DDoS attack",
        "Cryptojacking",
        "Phishing Attack",
        "Man-in-the-Middle Attack"
    ]

    #προσομοίωση εισερχόμενης κίνησης δικτύου και δημιουργία αποκρίσεων συμβάντων
    for index, row in synthetic_data.iterrows():
        incident_identification = row['IncidentIdentification']
        incident_summary = random.choice(attack_types)
        incident_notification = row['IncidentNotification']
        actions = row['Actions']

        #χρήση του IDS για την πρόβλεψη επιθέσεων
        if ids_model.predict(incident_summary) == "Attack":
            #εφόσον εντοπισθεί επίθεση δημιουργία απόκρισης συμβάντος
            print("++++++++++ Incident Report ++++++++++")
            print(synthetic_data.loc[[index]])
            print("++++++++++ Incident Response ++++++++++")
            response = enhanced_chatgpt_response.generate_response(
                incident_identification, incident_summary, incident_notification, actions
            )
            print(response)
            print("+" * 40)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification  IncidentSummary IncidentNotification  Actions
# 0                    ID1  Normal activity        Security Team  Monitor
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID1
# INCIDENT SUMMARY: Man-in-the-Middle Attack
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Monitor
# MATERIALS:
# 1.1 MATERIENTS
# 2.2 METHODS
# 3.3 MULTIPLE MIXED
# 4.4 MOST IMPORTANT INFORMATION
# 5.5 MENTIONED MESSAGES
# 6.6 MISC.
# 7.7 MATCHING MESSIONS
# 8.8 MECHANISMS
# 9.9 MACHINE GUNS AND MOUNTING GUN
# 10.10 MOUNTAIN GUN SIGHTING
# 11.12 MISSION
# 12.13 MUNITIONS AND OPERATIONS
# 13.14 MUTUAL AND PERSONAL INFORMATION MADE
# 14.15 MURDERING AND MISUSE OF MINE
# 15.16 MUSEUM OF MISSILE
# 16.17 MUSIC AND OTHER MODE
# 17.18 MOTHER'S MOUTH
# 18.19 MUMMY' SIZE
# 19.20 MOTHERS
# 20.21 MOMENTS OF SEX
# 21.22 MOURNING
# 22.23 MOUTES
# 23.24 MORTAL MENTALITIES
# 24.25 MOSES AND SOUNDS
# 25.26 MOSSES, MOBLEMS AND
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification  IncidentSummary IncidentNotification  Actions
# 1                    ID2  Normal activity        Security Team  Monitor
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID2
# INCIDENT SUMMARY: Man-in-the-Middle Attack
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Monitor
# MATERIALS:
# 1. A large number of people were injured in the attack.
# 2. The attack was carried out by a group of armed men. They were armed with knives and a large amount of ammunition. One of the attackers was killed. Two of them were wounded. Three of those injured were taken to hospital. Four of these were treated for injuries sustained in a separate attack on the same day. Five of their injuries were not life threatening. Six of our security personnel were killed in this attack and three of us were seriously injured. Seven of my security officers were also killed and one of ours was seriously wounded in an attack in which we were involved. Eight of all our personnel are in critical condition. Nine of this group were in serious condition and we are still in contact with them. Ten of you are all in our care. Eleven of your colleagues are also in your care and are being treated. Twelve of yours are not in any danger. You are safe. We are working with you to find out what happened. It is your responsibility to ensure that you have the best possible care for your loved ones. Your family and friends are very important to us. I am very grateful for all of that. And I want to thank you all for being
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification  IncidentSummary IncidentNotification  Actions
# 2                    ID3  Normal activity        Security Team  Monitor
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID3
# INCIDENT SUMMARY: Ransomware
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Monitor
# Ransom-related activity on the Internet is a growing problem in the United States. The FBI has identified a number of ransomware attacks that have been carried out by individuals who are trying to steal money from victims.
# The FBI is working with law enforcement agencies across the country to identify and disrupt the activity of these ransomware-based attacks. In addition, the FBI will continue to monitor the activities of individuals and organizations who have access to the information that is being collected by the National Security Agency.
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification  IncidentSummary IncidentNotification  Actions
# 3                    ID4  Normal activity        Security Team  Monitor
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID4
# INCIDENT SUMMARY: DDoS attack
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Monitor
# DDoS Attack
# The following information is provided to assist in the investigation of the D.C. Doxxing attack.
#
# 1. The D-Link Dxnet service was attacked on April 1, 2017. It was a DXnet attack that was carried out by a group of Daxxers. This attack was conducted by Dixxer.com, a company that is a part of a large Drexel University Drixx company. In this attack, Droxx was able to gain access to the network of servers that were being used by the attackers. As a result, the attack took place on the same day that the first Dexx server was compromised. On April 2, 2016, an unknown group attempted to take control of one of these servers. They attempted a denial of service attack on one server, but were unsuccessful. A second DEXX server that had been compromised was also compromised on that day. Both servers were successfully taken offline. At this time, there were no reports of any other Dxxx attacks. However, on May 1st, two DXXx servers, one belonging to a security firm and one to an individual, were compromised by an attack by unknown Dxxxx. These two servers are known to be vulnerable
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification  IncidentSummary IncidentNotification  Actions
# 4                    ID5  Normal activity        Security Team  Monitor
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID5
# INCIDENT SUMMARY: Man-in-the-Middle Attack
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Monitor
# MATERIALS:
# 1. A large number of people were injured in the attack.
# 2. The attack was carried out by a group of armed men. They were armed with knives and a large amount of ammunition. One of the attackers was killed. Two of them were wounded. Three of those injured were in critical condition. Four of these were taken to hospital. Five of their injuries were life threatening. Six of our officers were also injured. Seven of us were seriously injured and we are working with the police to get them back. Eight of all of this is being investigated. Nine of that is still under investigation. 10. We are still trying to determine the motive of what happened. 11. It is not clear what the motives were. 12. There is no evidence that this was a terrorist attack, but it is possible that it was. 13. This is a very serious attack and it will be a long time before we can say that we have found a motive. 14. I am not sure what it means. 15. But we will continue to investigate. 16. If we find a reason to believe that something was done, we would like to know what that means and what we should do. 17. In the meantime, I would urge you
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification        IncidentSummary IncidentNotification  \
# 5                    ID6  SQL injection attempt        Security Team
#
#                    Actions
# 5  Isolate and Investigate
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID6
# INCIDENT SUMMARY: Phishing Attack
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Isolate and Investigate
# ISLAMIC STATE:
# 1. The following is a list of the known and suspected phishing attacks that have been reported to the U.S. government.
# 2. A phisherlet is an attack that attempts to steal or steal information from a computer or device. It is used to gain access to a user's computer, device, or other information. This attack is not a phish attack. If you are a victim of phishers, you should immediately contact your local law enforcement agency. You should also contact the FBI or the National Security Agency. 3. An attacker can use a malicious program to obtain information about a person or a device and then use it to attack the victim. 4. Phishers can also use phishes to send malicious attachments to other computers or devices. 5. In some cases, phished emails can be used as a means to compromise a system or to cause a denial of service attack on a network. 6. Some phishable items can cause phagames to be sent to your computer. 7. Many phishy emails are sent by phisys. 8. There are many phyisies that can send phishly emails. 9. Most physys send emails to their victims. 10. They send messages to
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification        IncidentSummary IncidentNotification  \
# 6                    ID7  SQL injection attempt        Security Team
#
#                    Actions
# 6  Isolate and Investigate
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID7
# INCIDENT SUMMARY: Cryptojacking
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Isolate and Investigate
# ISSUES:
# 1. Crypto-Currency Exchange
# 2. Bitcoin Exchange (BCE)
# 3. Bitfinex
# 4. Coinmarketcap
# 5. Kraken
# 6. Bittrex
# 7. Coinbase
# 8. Mt. Gox
# 9. Ripple
# 10. BTCChina
# 11. LTC
# 12. Litecoin
# 13. Dash
# 14. Dogecoin (BTC)
#
#
# CryptoCurrencies Exchange is a Bitcoin exchange that is operated by Bitmain. It is an exchange of Bitcoin and Litecoins.
#
# Bitmain is the main Bitcoin trading platform. The BitMain team is responsible for the Bitcoin exchanges. They are responsible to ensure that the exchange is safe and secure.
#
# .BitMain is not responsible or liable for any losses or damages caused by the use of any of the Bitmessage services.
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification        IncidentSummary IncidentNotification  \
# 7                    ID8  SQL injection attempt        Security Team
#
#                    Actions
# 7  Isolate and Investigate
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID8
# INCIDENT SUMMARY: SQL injection attempt
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Isolate and Investigate
# ISSUES:
# 1. SQL Server 2012 R2
# 2. Windows Server 2008 R3
# 3. Microsoft SQL 2012
# 4. Oracle SQL 2013
# 5. MySQL
# 6. Apache
# 7. Redis
# 8. OpenSUSE
# 9. CentOS
# 10. RHEL
# 11. Ubuntu
# 12. Fedora
# 13. Debian
# 14. Gentoo
# 15. Linux Mint
# 16. FreeBSD
# 17. NetBSD
# 18. Solaris
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification        IncidentSummary IncidentNotification  \
# 8                    ID9  SQL injection attempt        Security Team
#
#                    Actions
# 8  Isolate and Investigate
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID9
# INCIDENT SUMMARY: Ransomware
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Isolate and Investigate
# ISSUES:
# 1. The following is a list of the known and suspected ransomware attacks that have been reported to the FBI.
# 2. This list is not exhaustive. It is based on information provided by the following individuals: 1. Anonymous
# Anonymous is an online group of hackers who use the Internet to steal and distribute malware. They are known to be active in the United States and abroad. 2. A.P.O.S. (Assault on Precincts)
# A. P. O. S. is the online security company that provides security services to law enforcement agencies. 3. Anon
# Anon is one of several online groups that are active online. 4. B.C.R.E.A (Bureau of Criminal Investigation) (Criminal Investigation Service of Canada) is another online organization that is active on the internet. 5. C.I.T.D.H.M.L.K.N.G.U.B.V.F.X.Y.Z.W.Q.J. and is also known as the "Criminologist" group. 6. D.Tech. Inc. has been active since 2009. 7. E.Mail.com has also been
# ++++++++++++++++++++++++++++++++++++++++
# ++++++++++ Incident Report ++++++++++
#   IncidentIdentification        IncidentSummary IncidentNotification  \
# 9                   ID10  SQL injection attempt        Security Team
#
#                    Actions
# 9  Isolate and Investigate
# ++++++++++ Incident Response ++++++++++
# INCIDENT IDENTIFICATION INFORMATION: ID10
# INCIDENT SUMMARY: Phishing Attack
# INCIDENT NOTIFICATION – OTHERS: Security Team
# ACTIONS: Isolate and Investigate
# ISLAMIC STATE:
# 1. The following is a list of the known and suspected phishing attacks that have been reported to the Security team.
# 2. A phisher is an attack that attempts to steal or steal information from a user's computer. It is usually a simple, malicious attack. This attack is not a threat to any user. However, it can be used to gain access to a computer, or to compromise a system. In this case, the attacker is likely to be a person who has access or has been compromised. If the phishers are not identified, they may be able to use the victim's identity to obtain information. For more information, see the following links: http://www.security.gov/security/phishing/
# 3. An attacker can use a phish to impersonate a victim. They can also use phishes to send a message to an attacker's account. These phished messages can include a link to their website, a URL, and a password. To impersonation, an individual can send the message using a different email address. When the email is sent, that email will be sent to that phishy email account, which will then be compromised and used by the attackers to access the computer and gain information
# ++++++++++++++++++++++++++++++++++++++++
